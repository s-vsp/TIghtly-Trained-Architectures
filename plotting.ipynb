# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(32,16))

sns.set_theme(style="dark")
sns.set(rc={'axes.facecolor': 'black', 'figure.facecolor': 'black'})

resnet = plt.Circle((4, 89.20), 1.2, color=(116/255, 30/255, 79/255), fill=True, alpha=0.8)
plt.gca().add_patch(resnet)

resnetC = plt.Circle((4, 89.20), 0.02, color="white", fill=True)
plt.gca().add_patch(resnetC)

vgg16 = plt.Circle((6, 91.23), 0.8, color=(116/255, 30/255, 79/255), fill=True, alpha=0.8)
plt.gca().add_patch(vgg16)

vgg16C = plt.Circle((6, 91.23), 0.02, color="white", fill=True)
plt.gca().add_patch(vgg16C)

swin = plt.Circle((8, 91.74), 0.5, color=(107/255, 140/255, 191/255), fill=True, alpha=0.8)
plt.gca().add_patch(swin)

swinC = plt.Circle((8, 91.74), 0.02, color="white", fill=True)
plt.gca().add_patch(swinC)

convnext = plt.Circle((10, 92.50), 0.5, color=(116/255, 30/255, 79/255), fill=True, alpha=0.8)
plt.gca().add_patch(convnext)

convnextC = plt.Circle((10, 92.50), 0.02, color="white", fill=True)
plt.gca().add_patch(convnextC)

convnextv2 = plt.Circle((12, 92.53), 0.5, color=(116/255, 30/255, 79/255), fill=True, alpha=0.8)
plt.gca().add_patch(convnextv2)

convnextv2C = plt.Circle((12, 92.53), 0.02, color="white", fill=True)
plt.gca().add_patch(convnextv2C)

convnextv223 = plt.Circle((14, 93), 0.01, color="black", fill=True, alpha=0.8)
plt.gca().add_patch(convnextv223)


plt.grid(axis='x', linestyle='--', linewidth=0.001)

sns.despine(left=True, bottom=True)

X_min = 0
Y_min = 88.0
X_max = 24
Y_max = 95.0

# Plot the data
#plt.scatter([X_min, X_max], [Y_min, Y_max], s=0.01)

# Set the x-axis ticks
plt.xticks(np.arange(0, 24, 1), color="white", fontsize=1)

# Set the y-axis ticks
plt.yticks(np.arange(88, 95.5, 0.75), color="white", fontsize=20)
plt.axis("equal")
plt.ylabel("Accuracy [%]", color="white", fontsize=30, labelpad=40)
plt.show()

# %%
plt.figure(figsize=(32,16))

sns.set_theme(style="dark")
sns.set(rc={'axes.facecolor': 'black', 'figure.facecolor': 'black'})

resnet = plt.Circle((-14, 49.56), 7.2, color=(116/255, 30/255, 79/255), fill=True, alpha=0.8)
plt.gca().add_patch(resnet)

resnetC = plt.Circle((-14, 49.56), 0.09, color="white", fill=True)
plt.gca().add_patch(resnetC)

vgg16 = plt.Circle((-1, 51.66), 4.8, color=(116/255, 30/255, 79/255), fill=True, alpha=0.8)
plt.gca().add_patch(vgg16)

vgg16C = plt.Circle((-1, 51.66), 0.09, color="white", fill=True)
plt.gca().add_patch(vgg16C)

swin = plt.Circle((12, 62.69), 3.0, color=(107/255, 140/255, 191/255), fill=True, alpha=0.8)
plt.gca().add_patch(swin)

swinC = plt.Circle((12, 62.69), 0.09, color="white", fill=True)
plt.gca().add_patch(swinC)

convnext = plt.Circle((25, 69.46), 3.0, color=(116/255, 30/255, 79/255), fill=True, alpha=0.8)
plt.gca().add_patch(convnext)

convnextC = plt.Circle((25, 69.46), 0.09, color="white", fill=True)
plt.gca().add_patch(convnextC)

convnextv2 = plt.Circle((38, 70.22), 3.0, color=(116/255, 30/255, 79/255), fill=True, alpha=0.8)
plt.gca().add_patch(convnextv2)

convnextv2C = plt.Circle((38, 70.22), 0.09, color="white", fill=True)
plt.gca().add_patch(convnextv2C)

convnextv223 = plt.Circle((14, 74), 0.01, color="black", fill=True, alpha=0.8)
plt.gca().add_patch(convnextv223)

plt.axis("equal")

plt.grid(axis='x', linestyle='--', linewidth=0.001)

sns.despine(left=True, bottom=True)


plt.xlim(left=0,right=24)
# Plot the data
#plt.scatter([X_min, X_max], [Y_min, Y_max], s=0.01)

# Set the x-axis ticks
#plt.xticks(np.arange(0, 24, 1), color="white", fontsize=1)

# Set the y-axis ticks
plt.yticks(np.arange(45., 80., 4.5), color="white", fontsize=20)
plt.xticks(np.arange(-20., 50., 10.), color="black")

plt.ylabel("Accuracy [%]", color="white", fontsize=30, labelpad=40)
plt.show()
